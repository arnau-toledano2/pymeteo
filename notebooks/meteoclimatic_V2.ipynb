# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import datetime

station_dataframes = []

url = "https://www.meteoclimatic.net/index/mapinfo/ESCAT?d=20231021&mp=0"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

def dms_to_decimal(dms_str):
    matches = re.match(r"(\d+)º (\d+)' (\d+)'' ([NSEW])", dms_str)
    if not matches:
        return None

    degrees, minutes, seconds, direction = matches.groups()
    decimal = float(degrees) + float(minutes)/60 + float(seconds)/3600
    
    if direction in ['S', 'W']:
        decimal = -decimal

    return decimal

station_links = [link for link in soup.select("a") if link.get('href') and link['href'].startswith('/perfil/')]

print()
print(f'{len(station_links)} stations were found!')
print()

for link in station_links:
   
    station_name = link.text.strip()  
    print(f'################### PROCESSING {station_name} ###################')
    print()
    station_url = "https://www.meteoclimatic.net" + link['href'].strip()  
    response2 = requests.get(station_url)
    station_soup = BeautifulSoup(response2.content, 'html.parser')
    
    # latitude & longitude
    lat_lon_elements = station_soup.find_all(string=lambda text: "º" in text and "''" in text)
    if lat_lon_elements and len(lat_lon_elements[0].split("\xa0\xa0\xa0\xa0")) >= 2:
        lat_str, lon_str = lat_lon_elements[0].split("\xa0\xa0\xa0\xa0")[0:2]
        latitude_decimal = dms_to_decimal(lat_str)
        longitude_decimal = dms_to_decimal(lon_str)
    #print(f'Latitude = {latitude_decimal}')
    #print(f'Longitude = {longitude_decimal}')
    
    # altitude
    altitude_pattern = r"\d+º.*\d+'' [NESW]\s+-\s+(\d+)"
    match_refined = re.search(altitude_pattern, station_soup.get_text())
    if match_refined:
        altitude_value = match_refined.group(1)
    else:
        altitude_value= "Altitude not found"
    #print()
    #print(f'Altitude = {altitude_value}')
    #print()
    
    current_weather_container = station_soup.find(string=lambda text: "EL TIEMPO ACTUAL" in text if text else False)
    if not current_weather_container:
        print("Current weather text not found")

    weather_data_table = current_weather_container.find_parent('table')
    if not weather_data_table:
        print("Weather data table not found")
    
    parent_container = weather_data_table.find_parent()
    parent_container_content = [str(child)[:500] for child in parent_container.children]
    weather_data_table_v2 = parent_container.find('table', cellpadding="2", cellspacing="1")
    weather_data_table_v2.prettify()[:500] if weather_data_table_v2 else "Table not found"
    rows_v2 = weather_data_table_v2.find_all('tr')
    headers = [header.get_text(strip=True) for header in rows_v2[0].find_all('td') if 'class' in header.attrs and 'titolet' in header.attrs['class']]
    headers.insert(3, 'Dirección Viento')
    
    data = []
    for row in rows_v2[1:]:
        row_data = [cell.get_text(strip=True) for cell in row.find_all('td') if 'class' not in cell.attrs or 'separador' not in cell.attrs['class']]
        if row_data:  
            data.append(row_data)
    
    structured_data = {
        "Temperatura": {},
        "Humedad": {},
        "Viento": {},
        "Presión": {},
        "Precip.": {},
        "Días Sequía": {}
    }
    
    def extract_wind_data(wind_data):
        parts = wind_data.split(' ')
        if len(parts) > 1:
            direction, speed = parts[0], parts[1]
        else:
            direction, speed = "", wind_data
        return direction, speed

    wind_direction, wind_speed = extract_wind_data(data[1][2])
    
    if len(data) > 1 and len(data[1]) > 5:
        structured_data["Temperatura"]["Actual"] = data[1][0]
        structured_data["Humedad"]["Actual"] = data[1][1]
        structured_data["Viento"]["Actual"] = {"Dirección": extract_wind_data(data[1][2])[0], "Velocidad": extract_wind_data(data[1][2])[1]}
        structured_data["Presión"]["Actual"] = data[1][3]
        structured_data["Precip."]["Actual"] = data[1][4]
        structured_data["Días Sequía"]["Actual"] = data[1][5]
    else:
        continue
        print(f"Not enough data for station: {station_name}")
        
    for time_period, row in zip(["Hoy", "Mes", "Año"], data[3:]):
        if len(row) > 1:
            structured_data["Temperatura"][time_period] = {"Máx.": row[1], "Mín.": row[2]} if len(row) > 2 else {"Máx.": row[1], "Mín.": None}
        else:
            structured_data["Temperatura"][time_period] = {"Máx.": None, "Mín.": None}
            print(f"Not enough temperature data for {time_period} in station: {station_name}")

        if len(row) > 4:
            structured_data["Humedad"][time_period] = {"Máx.": row[4], "Mín.": row[5]} if len(row) > 5 else {"Máx.": row[4], "Mín.": None}
        else:
            structured_data["Humedad"][time_period] = {"Máx.": None, "Mín.": None}
            print(f"Not enough humidity data for {time_period} in station: {station_name}")

        if len(row) > 7:
            structured_data["Viento"][time_period] = {"Máx.": row[7]}
        else:
            structured_data["Viento"][time_period] = {"Máx.": None}
            print(f"Not enough wind data for {time_period} in station: {station_name}")

        if len(row) > 9:
            structured_data["Presión"][time_period] = {"Máx.": row[9], "Mín.": row[10]} if len(row) > 10 else {"Máx.": row[9], "Mín.": None}
        else:
            structured_data["Presión"][time_period] = {"Máx.": None, "Mín.": None}
            print(f"Not enough pressure data for {time_period} in station: {station_name}")

        if len(row) > 12:
            structured_data["Precip."][time_period] = {"Total": row[12]}
        else:
            structured_data["Precip."][time_period] = {"Total": None}
            print(f"Not enough precipitation data for {time_period} in station: {station_name}")
    
    station_df = pd.DataFrame({
        'Station Name': [station_name],
        'Latitude': [latitude_decimal],
        'Longitude': [longitude_decimal],
        'Altitude': [altitude_value],
        'Temp_max': [structured_data["Temperatura"]["Hoy"]["Máx."]],
        'Temp_min': [structured_data["Temperatura"]["Hoy"]["Mín."]],
        'Wind_max': [structured_data["Viento"]["Hoy"]["Máx."]],
        'Precip': [structured_data["Precip."]["Hoy"]["Total"]],
    })

    numerical_columns = ['Latitude', 'Longitude', 'Altitude', 'Temp_max', 'Temp_min', 'Wind_max', 'Precip']
    for column in numerical_columns:
        station_df[column] = pd.to_numeric(station_df[column], errors='coerce')
    
    print(station_df.to_string(index=False))
    print()
    
    station_dataframes.append(station_df)

final_df = pd.concat(station_dataframes, ignore_index=True)
final_df = final_df.dropna() 

today = datetime.date.today()
date = today.strftime("%d%m%Y")
final_df.to_csv(f'meteoclimatic_{date}.csv', index=False)
# Out:
# 453 stations were found!
#
# ################### PROCESSING Cercedilla (Madrid) ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cercedilla (Madrid) 40.735278  -4.073056      1243      12.6       6.6        26     1.6
#
# ################### PROCESSING Aiguafreda ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#   Aiguafreda 41.768889   2.250278       420      21.2       5.4        20     0.0
#
# ################### PROCESSING Aiguafreda Aj. ###################
#
#   Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Aiguafreda Aj. 41.770833   2.250556       427      20.5       5.6        36     NaN
#
# ################### PROCESSING Alella-Mirador ###################
#
#   Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Alella-Mirador   41.4925   2.291389       290      18.9      12.9        39     0.0
#
# ################### PROCESSING Arenys de Mar ###################
#
#  Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Arenys de Mar 41.592778      2.565        85      19.8      11.7        45     NaN
#
# ################### PROCESSING Arenys de Munt ###################
#
#   Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Arenys de Munt 41.612778   2.540278       149      19.4      11.8        41     NaN
#
# ################### PROCESSING Argentona ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#    Argentona 41.558611     2.3925       127      19.9      11.9        31     0.0
#
# ################### PROCESSING Avià - Sud ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#   Avià - Sud 42.073611   1.827778       660      14.9       3.6        42     NaN
#
# ################### PROCESSING Badalona - Bufalà ###################
#
#      Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Badalona - Bufalà 41.461111   2.243611        70      21.3      12.1        13     0.0
#
# ################### PROCESSING Badalona - Centre ###################
#
#      Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Badalona - Centre 41.445833     2.2475        30      19.4      12.7        40     0.0
#
# ################### PROCESSING Badalona - Dalt la Vila ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Badalona - Dalt la Vila 41.459444   2.260278        37      20.9      12.3        26     NaN
#
# ################### PROCESSING Badalona - Llefià ###################
#
#      Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Badalona - Llefià 41.438889      2.225        25      19.8      12.7        45     0.0
#
# ################### PROCESSING Badalona - Progres ###################
#
#       Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Badalona - Progres    41.445   2.243333        33      19.9      12.9        34     0.0
#
# ################### PROCESSING Badia del Vallès ###################
#
# ################### PROCESSING Bagà (centre) ###################
#
#  Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Bagà (centre) 42.251667   1.863889       798      15.3       0.7        23     1.8
#
# ################### PROCESSING Bagà (nord) ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#  Bagà (nord) 42.257778   1.860278       865      15.5       0.6        13     NaN
#
# ################### PROCESSING Bagà (sud) ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#   Bagà (sud) 42.246667     1.8675       770      15.5      -0.1        24     1.2
#
# ################### PROCESSING Barcelona - Barri Gòtic ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Barri Gòtic 41.383333   2.177222        31      20.6      13.7        30     NaN
#
# ################### PROCESSING Barcelona - betevé ###################
#
#       Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - betevé 41.400556   2.193611        18      19.6      13.8        44     NaN
#
# ################### PROCESSING Barcelona - Bon Pastor ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Bon Pastor 41.434444   2.206389        16      19.8      13.5        13     NaN
#
# ################### PROCESSING Barcelona - Can Bruixa ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Can Bruixa 41.384167   2.133056        61      20.3      13.3        39     NaN
#
# ################### PROCESSING Barcelona - El Clot ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - El Clot 41.406667     2.1875        36      20.2      13.7        26     0.0
#
# ################### PROCESSING Barcelona - FEDAC Andreu ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - FEDAC Andreu  2.191389  41.432222        40       NaN       NaN       NaN     NaN
#
# ################### PROCESSING Barcelona - Fontcoberta ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Fontcoberta 41.395278   2.123889       110      19.7      12.8        15     NaN
#
# ################### PROCESSING Barcelona - Gràcia ###################
#
#       Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Gràcia 41.410556   2.163333       105      18.9      12.6        48     0.0
#
# ################### PROCESSING Barcelona - Hosp. Dexeus ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Hosp. Dexeus    41.385   2.126111        90      18.8      13.4        44     0.0
#
# ################### PROCESSING Barcelona - Hostafrancs ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Hostafrancs 41.373611   2.142222        40      19.2      13.5        11     NaN
#
# ################### PROCESSING Barcelona - La Pedrera ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - La Pedrera 41.404722   2.177222        45      19.5      13.5        40     NaN
#
# ################### PROCESSING Barcelona - La Verneda ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - La Verneda 41.423611   2.203333        30      19.7      13.6        39     0.0
#
# ################### PROCESSING Barcelona - Montbau ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Montbau     41.43   2.143056       210      19.2      10.8         7     NaN
#
# ################### PROCESSING Barcelona - Pl.de l'Aigua ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Pl.de l'Aigua 41.454167     2.1875        70      20.6      11.8        31     0.0
#
# ################### PROCESSING Barcelona - Plaça Sants ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Plaça Sants 41.371389   2.137778        40      18.8      13.2        47     0.0
#
# ################### PROCESSING Barcelona - Poblenou ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Poblenou 41.405278   2.206667        25      19.0      13.4        24     0.0
#
# ################### PROCESSING Barcelona - Ps. Sant Joan ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Ps. Sant Joan 41.398889   2.171667        28      20.2      13.6        35     NaN
#
# ################### PROCESSING Barcelona - Rectoret ###################
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Rectoret 41.425556   2.099722       320      17.9       9.7      1007     0.0
#
# ################### PROCESSING Barcelona - Sant Andreu ###################
#
# ################### PROCESSING Barcelona - Sant Andreu ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Sant Andreu 41.429722     2.1925        50      20.2      13.1        48     NaN
#
# ################### PROCESSING Barcelona - Sant Gervasi ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Sant Gervasi   41.4125   2.139167       160      19.3      11.8        35     0.0
#
# ################### PROCESSING Barcelona - Sant Martí ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Sant Martí     41.41   2.190833        20      19.6      13.8        35     0.0
#
# ################### PROCESSING Barcelona - Sarrià ###################
#
#       Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Sarrià    41.395     2.1225       110      19.3      12.3        35     0.0
#
# ################### PROCESSING Barcelona - Tibidabo ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Tibidabo 41.421667       2.12       512      17.5       8.3        45     0.0
#
# ################### PROCESSING Barcelona - Vallcarca ###################
#
#          Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona - Vallcarca 41.419444   2.131944       280      18.6      10.1        31     0.0
#
# ################### PROCESSING Barcelona Sants-Montjuïc ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Barcelona Sants-Montjuïc 41.375278   2.142222        45      19.3      13.3        32     0.0
#
# ################### PROCESSING Bellmunt ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#     Bellmunt 42.101389   2.293889      1241       9.1       0.5        63     0.0
#
# ################### PROCESSING Bellmunt - Santuari ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Bellmunt - Santuari 42.102778   2.296667      1246       8.9       0.5        63     0.0
#
# ################### PROCESSING Berga ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#        Berga 42.099167   1.846111       684      14.7       4.2        53     NaN
#
# ################### PROCESSING Cabrera de Mar ###################
#
#   Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cabrera de Mar 41.509167   2.401667         9      19.1      13.2        10     NaN
#
# ################### PROCESSING Cabrera de Mar-SJoan Munt ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cabrera de Mar-SJoan Munt 41.533056   2.392222       170      19.2      11.7        97     NaN
#
# ################### PROCESSING Cadí Est- PN Cadí-Moixeró ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cadí Est- PN Cadí-Moixeró 42.289722   1.739444      2440       3.4      -4.2       122    12.2
#
# ################### PROCESSING Caldes d'Estrac ###################
#
#    Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Caldes d'Estrac 41.574444   2.526944        72      17.6      11.2        35     0.0
#
# ################### PROCESSING Calella ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#      Calella 41.614167   2.664722         7      17.0      12.9        55     0.0
#
# ################### PROCESSING Calldetenes ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#  Calldetenes   41.9275   2.285556       488      18.0       2.5        45     NaN
#
# ################### PROCESSING Calldetenes (Est) ###################
#
#      Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Calldetenes (Est) 41.929444   2.295556       510      18.0       2.1        33     0.0
#
# ################### PROCESSING Canet de Mar ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Canet de Mar 41.590278   2.576944        40      18.4      12.4        42     NaN
#
# ################### PROCESSING Canet de Mar ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Canet de Mar 41.586944   2.577222        42      17.8      12.4        47     NaN
#
# ################### PROCESSING Canet de Mar - Mise ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Canet de Mar - Mise 41.595833   2.576944        70      19.6      11.3        31     NaN
#
# ################### PROCESSING Canet de Mar - Rial Oms ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Canet de Mar - Rial Oms 41.595278   2.585278        50       NaN       NaN       NaN     NaN
#
# ################### PROCESSING Canovelles - Rec ###################
#
# ################### PROCESSING Cànoves i Samalús ###################
#
#      Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cànoves i Samalús 41.689722   2.353333       338      20.2       8.7        42     NaN
#
# ################### PROCESSING Cantallops ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#   Cantallops 41.369167   1.802222       280      18.9       9.3        31     0.0
#
# ################### PROCESSING Canyelles - Daltmar ###################
#
# ################### PROCESSING Cardedeu - Centre ###################
#
#      Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cardedeu - Centre 41.636944   2.358889       203      21.1       9.7        26     NaN
#
# ################### PROCESSING Cardedeu - Poble Sec ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cardedeu - Poble Sec 41.636944   2.358056       200      21.5      10.1        37     NaN
#
# ################### PROCESSING Cardona ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#      Cardona 41.913889   1.678611       520      12.8      12.8        31     0.0
#
# ################### PROCESSING Cardona - Turó Rossinyol ###################
#
# ################### PROCESSING Cardona_RavalSantJoan_DV ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cardona_RavalSantJoan_DV 41.921111   1.683056       444      14.4       5.1        26     0.0
#
# ################### PROCESSING Carme ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#        Carme     41.53   1.616111       350      21.6       6.9        24     0.0
#
# ################### PROCESSING Casserres ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#    Casserres 42.011389   1.847778       614      13.9       4.3        28     0.0
#
# ################### PROCESSING Castellar del Vallès ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Castellar del Vallès 41.618611   2.093056       331      21.2       8.4        31     NaN
#
# ################### PROCESSING Castellbell (Baix Vilar) ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Castellbell (Baix Vilar) 41.636667      1.855       187      21.8       6.7        24     NaN
#
# ################### PROCESSING Castellbell (El Borràs) ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Castellbell (El Borràs) 41.633889   1.863889       166      21.6       6.9        48     0.0
#
# ################### PROCESSING Castelldefels ###################
#  Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Castelldefels   41.2675      1.935        62      18.7      13.4        29     0.0
#
# ################### PROCESSING Castellgali ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#  Castellgali       NaN   1.837778       266      21.7       7.1        23     0.0
#
# ################### PROCESSING Castellterçol ###################
#
#  Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Castellterçol 41.752222   2.128333       729      17.4       2.7        15     NaN
#
# ################### PROCESSING Centelles ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#    Centelles 41.775278   2.241389       500      19.1       5.3        26     NaN
#
# ################### PROCESSING Centelles - Oest ###################
#
#     Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Centelles - Oest 41.797222        NaN       547      19.4       5.4        40     NaN
#
# ################### PROCESSING Cercs ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#        Cercs 42.150556   1.855556       575      15.2       3.0        17     NaN
#
# ################### PROCESSING Cerdanyola - Centre ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cerdanyola - Centre 41.490278   2.136944       110      20.7      11.3        39     NaN
#
# ################### PROCESSING Cerdanyola - Montflorit ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cerdanyola - Montflorit    41.485   2.133056        80      20.8       9.3         6     0.0
#
# ################### PROCESSING Cerdanyola Ateneu ###################
#
#      Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cerdanyola Ateneu 41.488611   2.140278       108      21.4      11.2        31     0.0
#
# ################### PROCESSING Cervelló - Penya Roja ###################
#
#          Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cervelló - Penya Roja 41.402778   1.945833       357      20.9      10.1        30     NaN
#
# ################### PROCESSING Collbató(can dalmases) ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Collbató(can dalmases) 41.562222   1.798333       410      18.8       7.7        21     0.0
#
# ################### PROCESSING Collsuspina - Centre ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Collsuspina - Centre 41.827222   2.176389       901      14.9       3.5        45     NaN
#
# ################### PROCESSING Corbera de Llobregat ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Corbera de Llobregat 41.409722   1.892222       456      18.4       8.0        46     NaN
#
# ################### PROCESSING Cornellà - Gavarra ###################
#
#       Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cornellà - Gavarra 41.359722   2.076389        42      15.4      12.3        10     0.0
#
# ################### PROCESSING Cornet (Sallent) ###################
#
#     Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cornet (Sallent)      41.9   1.953056       465      15.9       3.7        26     NaN
#
# ################### PROCESSING Cussons - Sora ###################
#
#   Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cussons - Sora 42.096667   2.195278       636      14.4      -0.1        50     0.0
#
# ################### PROCESSING Dosrius ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#      Dosrius 41.596111   2.404444       165      20.9       8.1        30     NaN
#
# ################### PROCESSING Dosrius Can Miloca ###################
#
#       Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Dosrius Can Miloca       NaN        NaN       488      17.6       7.5        24     0.0
#
# ################### PROCESSING El Masnou - Ocata ###################
#
#      Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# El Masnou - Ocata    41.485   2.332222        10      19.0      13.4        43     0.0
#
# ################### PROCESSING El Masnou -carrte -Alella ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# El Masnou -carrte -Alella 41.479167   2.342222        27      17.5      12.8        27     0.0
#
# ################### PROCESSING El Papiol ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#    El Papiol 41.437222   2.008056       105      20.3      10.8        47     NaN
#
# ################### PROCESSING El Prat-Zonilla ###################
#
#    Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# El Prat-Zonilla 41.318056      2.085         4       NaN       NaN       NaN     NaN
#
# ################### PROCESSING El Serrat de Castellnou ###################
#
# ################### PROCESSING Els Monjos ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#   Els Monjos 41.321111   1.662778       180      18.2      10.4        31     NaN
#
# ################### PROCESSING Fals (Bages) ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Fals (Bages) 41.743056   1.712778       400      19.6       7.2        24     NaN
#
# ################### PROCESSING Figaró Montmany ###################
#
#    Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Figaró Montmany 42.721111   2.272778       317      19.8       7.2        34     NaN
#
# ################### PROCESSING Folgueroles ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#  Folgueroles 41.940556     2.3175       545      16.7       3.1        18     0.0
#
# ################### PROCESSING Fonollosa ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#    Fonollosa 41.760278   1.726111       360      20.6       3.3        18     NaN
#
# ################### PROCESSING Font-Rubí ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#    Font-Rubí 41.430556   1.588611       550      18.7       7.7        29     NaN
#
# ################### PROCESSING Gaià ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#         Gaià 41.918889      1.965       558       NaN       NaN       NaN     NaN
#
# ################### PROCESSING Gavà ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#         Gavà 41.306111      1.995        45      19.5      12.9        47     NaN
#
# ################### PROCESSING Gavà - Colomeres ###################
#
#     Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Gavà - Colomeres 41.306944   1.999167        45      19.8      12.8        31     0.0
#
# ################### PROCESSING Gavà - Gavà Nova ###################
#
#     Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Gavà - Gavà Nova 41.308611   1.993611        40      20.1      13.3        20     NaN
#
# ################### PROCESSING Granollers ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#   Granollers      41.6   2.283056       190      20.3      10.6        50     0.0
#
# ################### PROCESSING Gualba ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#       Gualba 41.719444       2.53       164      21.1       7.4        55     NaN
#
# ################### PROCESSING Gurb ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#         Gurb 41.973889   2.238056       525      15.8       2.2        53     NaN
#
# ################### PROCESSING L'Ametlla del Vallès ###################
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# L'Ametlla del Vallès 41.699167   2.243611       647      17.8       7.8        34     0.0
#
# ################### PROCESSING L'Espunyola ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#  L'Espunyola 42.052222   1.772778       802      13.0       2.9        34     0.2
#
# ################### PROCESSING La Batllòria - Vallès Ori ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# La Batllòria - Vallès Ori 41.718056   2.547778        97      21.8       7.0        40     NaN
#
# ################### PROCESSING La Beguda Alta ###################
#
#   Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# La Beguda Alta 41.497222   1.836111       285      19.6       8.6        27     0.0
#
# ################### PROCESSING La Floresta (St Cugat) ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# La Floresta (St Cugat) 41.443056   2.066667       202      20.3      10.2        22     NaN
#
# ################### PROCESSING La Font del Bosc -Mediona ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# La Font del Bosc -Mediona 41.484722   1.661667       553      19.3       6.2        35     NaN
#
# ################### PROCESSING La Garriga (Ajuntament) ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# La Garriga (Ajuntament) 41.685278   2.285556       247      20.9       8.3        37     0.0
#
# ################### PROCESSING La Nou de Berguedà Insula ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# La Nou de Berguedà Insula 42.169167   1.889722       940      14.3       1.7        24     NaN
#
# ################### PROCESSING La Pobla de Lillet ###################
#
#       Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# La Pobla de Lillet    42.245      1.975       873      13.7       0.7        21     0.0
#
# ################### PROCESSING Lavern ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#       Lavern 41.394167       1.77       217      19.3      11.0        35     0.0
#
# ################### PROCESSING Les Pinedes de l'Armengol ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Les Pinedes de l'Armengol 41.512222      1.635       550      19.8       6.7        37     0.0
#
# ################### PROCESSING Malgrat de mar ###################
#
#   Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Malgrat de mar 41.646389   2.741111         4      17.8       9.6        50     0.0
#
# ################### PROCESSING Manlleu ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#      Manlleu 42.001389   2.290278       460      17.0       3.4        34     0.0
#
# ################### PROCESSING Manresa ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#      Manresa 41.720278   1.839444       251      20.4       9.3        30     0.0
#
# ################### PROCESSING Marganell ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#    Marganell 41.640278   1.790833       305      20.8       6.3        37     0.0
#
# ################### PROCESSING Martorell - LA MERCÈ ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Martorell - LA MERCÈ 41.473611       1.93        56      23.5      10.1        19     0.0
#
# ################### PROCESSING Matadepera - Centre ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Matadepera - Centre 41.599444   2.028056       426      20.6       7.2        29     0.0
#
# ################### PROCESSING Matadepera-La Muntanyeta ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Matadepera-La Muntanyeta 41.603056   2.027778       515      18.8       7.3        23     0.0
#
# ################### PROCESSING Mataró - Can Quirze ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Mataró - Can Quirze 41.553333   2.461111        80      18.8      12.4        15     0.0
#
# ################### PROCESSING Mataró - Vista Alegre ###################
#
#          Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Mataró - Vista Alegre 41.553056   2.447778       105      19.2      12.0        45     0.0
#
# ################### PROCESSING Mataró -Nord ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Mataró -Nord 41.556111   2.436389       144      20.5      11.1        39     NaN
#
# ################### PROCESSING Mataró-Can Canyellas ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Mataró-Can Canyellas 41.556667   2.436944       144      19.5      11.3        47     NaN
#
# ################### PROCESSING Mataró-Parc de Créteil ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Mataró-Parc de Créteil 41.552778   2.447222       105      19.8      11.7        40     NaN
#
# ################### PROCESSING Moià ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#         Moià 41.812222   2.101944       705      16.8       4.2        23     NaN
#
# ################### PROCESSING Moià - Oest ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#  Moià - Oest 41.812778   2.091111       735      16.7       4.0        19     0.0
#
# ################### PROCESSING Molins de Rei - Bonavista ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Molins de Rei - Bonavista 41.414722   2.019444        49      20.9      10.4        26     0.0
#
# ################### PROCESSING Molins de Rei - Estel ###################
#
#          Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Molins de Rei - Estel 41.410556     2.0225        64      21.4      11.9        39     0.0
#
# ################### PROCESSING Molins de Rei-de les eres ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Molins de Rei-de les eres 41.412778   2.018056        37      20.9      11.1        35     0.0
#
# ################### PROCESSING Mollet  -  Estació França ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Mollet  -  Estació França 41.534722   2.216389        65      20.8      11.4        34     0.0
#
# ################### PROCESSING Mollet - Barri Santa Rosa ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Mollet - Barri Santa Rosa 41.534722   2.183333        75      20.8      11.5        34     0.0
#
# ################### PROCESSING Mollet del Vallès ###################
#
#      Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Mollet del Vallès 41.542222     2.2225        66      21.6      10.8        11     NaN
#
# ################### PROCESSING Monistrol de Calders ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Monistrol de Calders 41.760278     2.0125       465      20.2       3.4        16     0.0
#
# ################### PROCESSING Montmeló-T.de la Bandera ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Montmeló-T.de la Bandera 41.556667   2.248056       112      21.6      11.2        26     0.0
#
# ################### PROCESSING Montornés del V. - Lluch ###################
# ################### PROCESSING Montornès del Vallès ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Montornès del Vallès 41.541667   2.266389       100      20.4      11.5        13     NaN
#
# ################### PROCESSING Montseny - Can Cervera ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Montseny - Can Cervera     41.77   2.390833       710      18.1       7.6        43     0.0
#
# ################### PROCESSING Montseny - Les Arrels ###################
#
#          Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Montseny - Les Arrels 41.760556   2.393889       435      20.4       8.8        27     NaN
#
# ################### PROCESSING Olesa Montserrat-Eixample ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Olesa Montserrat-Eixample 41.540556   1.895556       110      22.3      10.2        17     0.0
#
# ################### PROCESSING Olost - Mas Lliscàs ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Olost - Mas Lliscàs 41.979167   2.099167       558      15.6       0.6        44     0.0
#
# ################### PROCESSING Palau Solità i P. Castell ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Palau Solità i P. Castell   41.5775   2.185278       150      13.6      10.3        15     NaN
#
# ################### PROCESSING Palau-solità i P. Cortés ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Palau-solità i P. Cortés    41.585   2.176944       125      22.0      10.9        35     0.0
#
# ################### PROCESSING Piera ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#        Piera 41.519444   1.751111       312      19.7       8.1        34     0.0
#
# ################### PROCESSING Pineda de Mar - Centre ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Pineda de Mar - Centre 41.623889   2.691111         9      17.6       9.7        37     NaN
#
# ################### PROCESSING Pineda de Mar - Les Creus ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Pineda de Mar - Les Creus 41.622222   2.670556        30      17.8       7.2        50     NaN
#
# ################### PROCESSING Pineda de Mar - Nord ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Pineda de Mar - Nord 41.636111   2.687222        45      17.7       9.1        50     0.0
#
# ################### PROCESSING Premià de Dalt ###################
#
#   Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Premià de Dalt 41.500278   2.356944        40      19.0      13.0        44     NaN
#
# ################### PROCESSING Premià de Mar - Est ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Premià de Mar - Est 41.494167   2.368611        15      20.2      13.2        34     0.0
#
# ################### PROCESSING Premià de Mar - Nord ###################
#
# ################### PROCESSING Ripollet ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#     Ripollet 41.501111   2.155556        36      21.6      11.6        41     NaN
#
# ################### PROCESSING Rocafort ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#     Rocafort 41.715833   1.935278       430       NaN       NaN       NaN     NaN
#
# ################### PROCESSING Rocafort, Can Lleonart ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Rocafort, Can Lleonart 41.718333   1.916944       472      19.2       7.9        31     0.0
#
# ################### PROCESSING Roda de Ter - Escorxador ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Roda de Ter - Escorxador 41.978889       2.31       457      17.8       1.9        39     NaN
#
# ################### PROCESSING Roda de Ter - Pla Xic ###################
#
#          Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Roda de Ter - Pla Xic 41.989444   2.314167       470      17.3       1.9        42     NaN
#
# ################### PROCESSING Roda de Ter-l'Esquerda ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Roda de Ter-l'Esquerda 41.975556     2.3125       473      18.1       1.8        39     0.0
#
# ################### PROCESSING Rubí - La Serreta ###################
#
#      Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Rubí - La Serreta 41.498333   2.036389       180      20.4      10.0        33     NaN
#
# ################### PROCESSING Rubí - Pl S.Allende ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Rubí - Pl S.Allende 41.490556   2.030833       130      21.4      10.5        20     NaN
#
# ################### PROCESSING S. Cugat Val. La Floresta ###################
#
# Not enough precipitation data for Hoy in station: S. Cugat Val. La Floresta
# Not enough precipitation data for Mes in station: S. Cugat Val. La Floresta
# Not enough precipitation data for Año in station: S. Cugat Val. La Floresta
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# S. Cugat Val. La Floresta 41.446944   2.084167       217      19.2      10.1        22     NaN
#
# ################### PROCESSING S.M.Montbui - N.Antic ###################
#
#          Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# S.M.Montbui - N.Antic 41.554444   1.603056       407      21.8       6.6        28     0.0
#
# ################### PROCESSING Sabadell - Can Rull ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sabadell - Can Rull 41.555556   2.085278       220      20.7      10.1        30     0.0
#
# ################### PROCESSING Sabadell - Centre ###################
#
#      Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sabadell - Centre 41.547222   2.114444       197      21.0      10.7        34     NaN
#
# ################### PROCESSING Sabadell - Creu Alta ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sabadell - Creu Alta 41.562778   2.100278       210      20.9      10.8        13     0.0
#
# ################### PROCESSING Sabadell - Viena ###################
#
#     Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sabadell - Viena 41.559167       2.08       212      21.0       9.8        24     NaN
#
# ################### PROCESSING Sallent [El Bages] ###################
#
#       Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sallent [El Bages] 41.826667   1.899722       336      17.4       5.8        23     NaN
#
# ################### PROCESSING Sant Andreu de la B-Palau ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Andreu de la B-Palau   41.4525   1.961667        88      21.3      10.5        37     NaN
#
# ################### PROCESSING Sant Andreu de la Barca ###################
#
# ################### PROCESSING Sant Boi - C. Cooperativa ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Boi - C. Cooperativa 41.356111   2.026944        41      19.4      12.0        53     NaN
#
# ################### PROCESSING Sant Boi - Molí Nou ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Boi - Molí Nou 41.366667   2.034444        26      19.8      12.3        39     0.0
#
# ################### PROCESSING Sant Boi de Llobregat ###################
#          Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Boi de Llobregat     41.35   2.027778        50      19.9      11.2         0     NaN
#
# ################### PROCESSING Sant Boi Ll. - Marianao ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Boi Ll. - Marianao   41.3475   2.031389        36      20.1      12.2        31     NaN
#
# ################### PROCESSING Sant Celoni - Diputació ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Celoni - Diputació     41.69   2.486667       170      20.6      10.8        45     0.0
#
# ################### PROCESSING Sant Celoni - El temple ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Celoni - El temple 41.683333   2.480556       150      21.0      11.1         0     0.0
#
# ################### PROCESSING Sant Celoni - Univers ###################
#
#          Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Celoni - Univers 41.691944   2.490556       158      20.5      11.0        27     0.0
#
# ################### PROCESSING Sant Celoni - Vilardell ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Celoni - Vilardell 41.684444   2.523333       240      20.4      11.1        13     NaN
#
# ################### PROCESSING Sant Celoni-Major de Dalt ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Celoni-Major de Dalt 41.688611   2.488611       180      21.1      11.0        37     NaN
#
# ################### PROCESSING Sant Climent de Llobregat ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Climent de Llobregat 41.337222   1.997778       100      21.9      10.0        18     NaN
#
# ################### PROCESSING Sant Cugat ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#   Sant Cugat 41.458333   2.047778       127      21.3      11.0        26     NaN
#
# ################### PROCESSING Sant Cugat Sesgarrigues ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Cugat Sesgarrigues 41.364167   1.753333       260      19.0       9.8        24     NaN
#
# ################### PROCESSING Sant Esteve Sesrovires ###################
#
# ################### PROCESSING Sant Esteve Sesrovires N ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Esteve Sesrovires N 41.500556   1.860278       215      20.1       9.9        42     NaN
#
# ################### PROCESSING Sant Feliu de Codines ###################
#
# ################### PROCESSING Sant Feliu de Codines Est ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Feliu de Codines Est 41.685278   2.165556       412      21.0       9.5        16     0.6
#
# ################### PROCESSING Sant Feliu de Llob.El Pla ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Feliu de Llob.El Pla 41.380833   2.028611        21      20.0      11.1        50     0.0
#
# ################### PROCESSING Sant Feliu de Llobregat ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Feliu de Llobregat 41.385556   2.047222        48      19.8      12.1        32     0.0
#
# ################### PROCESSING Sant Feliu Llob - Mestral ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Feliu Llob - Mestral 41.394722   2.051111       112      19.6      11.4        45     NaN
#
# ################### PROCESSING Sant Feliu Llob.S.Josep ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Feliu Llob.S.Josep       NaN   2.034167        28      20.2      10.4        50     NaN
#
# ################### PROCESSING Sant Fost - La Conreria ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Fost - La Conreria 41.504722   2.250556       300      18.3       9.2        44     0.0
#
# ################### PROCESSING Sant Fost - Mas Llombart ###################
#
# ################### PROCESSING Sant Julià d Vilatorta Aj ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Julià d Vilatorta Aj 41.927222   2.317222       578      16.9       1.9        34     NaN
#
# ################### PROCESSING Sant Julià de Cerdanyola ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Julià de Cerdanyola 42.221389   1.894167       980      13.8      -0.2        35     NaN
#
# ################### PROCESSING Sant Julià de Vilatorta ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Julià de Vilatorta 41.924722   2.318056       570      17.1       2.1        37     NaN
#
# ################### PROCESSING Sant Marti Sescorts ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Marti Sescorts 42.015556   2.320278       515      17.7       1.6        24     0.0
#
# ################### PROCESSING Sant Pau D'Ordal ###################
#
#     Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Pau D'Ordal   41.3825   1.794167       240      19.1       9.6        45     0.0
#
# ################### PROCESSING Sant Pere de Casserres ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Pere de Casserres 42.001389   2.340556       486      17.1       3.1        48     0.0
#
# ...
#   Suterranya 42.152222   0.948333       561       8.2       3.8         7     NaN
#
# ################### PROCESSING Tuixent ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#      Tuixent 42.230556   1.566389      1125       9.6       0.3        23     NaN
#
# ################### PROCESSING Tuixent - La Vansa ###################
#
#       Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Tuixent - La Vansa 42.214167   1.527222      1900       5.3      -1.4        76     2.0
#
# ################### PROCESSING Vilanova de la Barca ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Vilanova de la Barca 41.690556   0.727778       208      18.5       7.3        17     NaN
#
# ################### PROCESSING Vinaixa - Ctra. de Lleida ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Vinaixa - Ctra. de Lleida 41.428333   0.974722       485      19.7       7.2        16     NaN
#
# ################### PROCESSING Albinyana ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#    Albinyana 41.245278   1.487222       195      19.4      12.4        27     0.0
#
# ################### PROCESSING Alcanar - St. Antoni ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Alcanar - St. Antoni   40.5625   0.458333        83      24.7      12.6        42     0.0
#
# ################### PROCESSING Almoster - Picarany ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Almoster - Picarany 41.196944   1.096944       348      19.9       9.7        19     0.0
#
# ################### PROCESSING Almoster - Sud ###################
#
#   Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Almoster - Sud 41.190833   1.108611       255      19.9      10.3        24     NaN
#
# ################### PROCESSING Banyeres del Penedès ###################
#
#         Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Banyeres del Penedès 41.278889   1.581389       165      18.4      10.6        24     0.0
#
# ################### PROCESSING Belltall ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#     Belltall 41.586667   1.186667       780      17.3       5.6        35     NaN
#
# ################### PROCESSING Bellvei ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#      Bellvei 41.238889   1.578889       107      18.1      10.8        31     NaN
#
# ################### PROCESSING Bellvei - Baronia de Mar ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Bellvei - Baronia de Mar 41.213889   1.563611       120      17.5      11.5        22     NaN
#
# ################### PROCESSING Cabassers ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#    Cabassers 41.248889   0.748889       606      21.5       7.4        32     NaN
#
# ################### PROCESSING Camarles ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#     Camarles 40.779167   0.675278        11      20.8      10.2        15     0.0
#
# ################### PROCESSING Cambrils ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#     Cambrils 41.075556   1.051111        30      23.1      11.9         7     NaN
#
# ################### PROCESSING Cambrils l'Eixample ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cambrils l'Eixample 41.069444   1.051667        35      20.0      12.0        21     NaN
#
# ################### PROCESSING Colldejou ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#    Colldejou 41.099444   0.887778       436      20.0       7.6        25     0.0
#
# ################### PROCESSING Coma-ruga ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#    Coma-ruga 41.192222   1.520833        31      18.6      10.4        18     NaN
#
# ################### PROCESSING Coma-ruga (El Vendrell) ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Coma-ruga (El Vendrell)   41.1825   1.521944         4      18.2      12.4        18     0.0
#
# ################### PROCESSING Conesa ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#       Conesa 41.517222   1.291389       705      17.4       5.6        24     NaN
#
# ################### PROCESSING Constantí ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#    Constantí   41.1525   1.214167        87      19.0      11.3        32     0.0
#
# ################### PROCESSING Cornudella de Montsant ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Cornudella de Montsant 41.265833   0.906667       533      21.9       7.8        18     NaN
#
# ################### PROCESSING creixell ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#     creixell 41.164167   1.426111        59      18.7      10.9        15     0.0
#
# ################### PROCESSING Darmós ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#       Darmós 41.074722   0.751111       185      21.9       7.9        17     0.0
#
# ################### PROCESSING Duesaigües ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#   Duesaigües 41.149167      0.935       322      19.3       8.2         9     NaN
#
# ################### PROCESSING El Papiolet ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#  El Papiolet 41.282222   1.528333       163      21.7       9.9        26     NaN
#
# ################### PROCESSING El Priorat de Banyeres ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# El Priorat de Banyeres 41.273889   1.540278       148      19.8      10.7        20     0.0
#
# ################### PROCESSING El Vendrell - Televisió ###################
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# El Vendrell - Televisió 41.225556   1.538056        57      18.3      11.7        31     0.0
#
# ################### PROCESSING Els Pallaresos ###################
#
#   Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Els Pallaresos 41.175556   1.269167       125      19.4      12.7        45     0.0
#
# ################### PROCESSING Falset ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#       Falset 41.146667   0.818611       367      21.4       4.1         0     0.4
#
# ################### PROCESSING Falset - Baboix ###################
#
#    Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Falset - Baboix 41.140278   0.825556       370      21.9       4.2         0     0.6
#
# ################### PROCESSING Falset - Els Masos ###################
#
#       Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Falset - Els Masos 41.174444   0.827222       375      20.8       4.6        15     0.4
#
# ################### PROCESSING Falset - les esplanes ###################
#
#          Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Falset - les esplanes 41.154167   0.803056       320      21.9       5.1        15     0.4
#
# ################### PROCESSING Falset - Les Torres ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Falset - Les Torres 41.142778   0.838056       570      20.6       7.1        39     0.0
#
# ################### PROCESSING Glorieta ###################
#
# ################### PROCESSING Hosp.de l'Infant - Centre ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Hosp.de l'Infant - Centre   40.9925   0.922778        42      19.1      11.4        23     NaN
#
# ################### PROCESSING L'Arboç ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#      L'Arboç 41.281667   1.614167       166      18.2      10.9        31     0.0
#
# ################### PROCESSING L'Arboç - N340 ###################
#
#   Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# L'Arboç - N340 41.264444   1.602778       153      18.8      10.3        23     NaN
#
# ################### PROCESSING L'Arboç Can Suriol ###################
#
# ################### PROCESSING La Pobla de Massaluca ###################
#
#          Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# La Pobla de Massaluca 41.182222   0.354444       362      22.0       9.1        28     NaN
#
# ################### PROCESSING La Riba ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#      La Riba 41.315833   1.174722       332      18.8       8.0        32     NaN
#
# ################### PROCESSING La Selva del Camp (INS) ###################
#
#            Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# La Selva del Camp (INS) 41.211111   1.132222       259      19.9       9.6        32     0.0
#
# ################### PROCESSING La Sénia ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#     La Sénia 40.637222     0.2775       370      23.0       9.6        58     NaN
#
# ################### PROCESSING La Torregassa ###################
#
#  Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# La Torregassa 41.286389   1.521944       200      19.6       9.6        24     NaN
#
# ################### PROCESSING La Vilella Baixa ###################
#
#     Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# La Vilella Baixa 41.220833   0.762778       240      23.3       7.8        14     0.8
#
# ################### PROCESSING Les Moreres - Bonastre ###################
#
#           Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Les Moreres - Bonastre 41.223333   1.441667       187      19.2       9.0        26     0.0
#
# ################### PROCESSING Montblanc ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#    Montblanc 41.373611   1.163333       348      20.0       8.4        32     NaN
#
# ################### PROCESSING Montblanc -Centre ###################
#
#      Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Montblanc -Centre 41.383333   1.166944       352      21.0       9.5        16     0.6
#
# ################### PROCESSING Querol (poble) ###################
#
#   Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Querol (poble) 41.421111   1.395833       560      19.1       5.1        66     0.4
#
# ################### PROCESSING Querol Can Llenas ###################
#
#      Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Querol Can Llenas 41.399167   1.441111       660      16.7       5.3        18     0.2
#
# ################### PROCESSING Querol-920m Formigosa ###################
#
#          Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Querol-920m Formigosa   41.4225   1.438611       920      16.3       5.3        45     0.3
#
# ################### PROCESSING Reus -  Velòdrom ###################
#
#     Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Reus -  Velòdrom 41.149167   1.103611       110      20.6      10.8        17     NaN
#
# ################### PROCESSING Reus - Carme ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Reus - Carme 41.153333   1.106389       142      20.9      10.7        15     NaN
#
# ################### PROCESSING Reus - Centre ###################
#
#  Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Reus - Centre 41.154167      1.105       147      19.6      11.1        21     0.0
#
# ################### PROCESSING Reus - Manyanet ###################
#
#    Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Reus - Manyanet   41.1475   1.100556       111      19.8      10.4        16     0.0
#
# ################### PROCESSING Reus - Nord ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#  Reus - Nord 41.165833     1.1075       150      20.3      10.3        18     NaN
#
# ################### PROCESSING Reus - Vallroquetes ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Reus - Vallroquetes 41.156111   1.109722       143      19.1      11.3        18     NaN
#
# ################### PROCESSING Riudoms ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#      Riudoms 41.137222   1.048611       130      20.8      10.6        25     NaN
#
# ################### PROCESSING Riudoms Nort ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Riudoms Nort 41.151667   1.060556       147      19.8      10.8        14     NaN
#
# ################### PROCESSING Sant Carles de la Rapita ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Sant Carles de la Rapita   40.6225     0.5925        65      22.4      11.7        48     0.0
#
# ################### PROCESSING Tarragona-Fortí St.Jordi ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Tarragona-Fortí St.Jordi 41.116111      1.265        40      18.1      13.2        26     0.0
#
# ################### PROCESSING Torredembarra - C/Pandols ###################
#
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Torredembarra - C/Pandols 41.140278   1.401667         5      18.0      11.9        11     0.0
#
# ################### PROCESSING Ulldecona - Pou Jua ###################
#
#        Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Ulldecona - Pou Jua 40.621667   0.400278       175      25.2       8.6        39     0.0
#
# ################### PROCESSING Ulldecona-S. Joan del Pas ###################
#              Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Ulldecona-S. Joan del Pas 40.607778   0.380833       205      25.0       8.7        45     NaN
#
# ################### PROCESSING Vallfogona de Riucorb ###################
#
#          Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Vallfogona de Riucorb 41.564167   1.237778       575      19.4       6.9        27     NaN
#
# ################### PROCESSING Vallmoll ###################
#
# Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
#     Vallmoll 41.258611     1.2475       205      20.4       9.6        19     0.0
#
# ################### PROCESSING Valls - IES Narcís Oller ###################
#
#             Station Name  Latitude  Longitude  Altitude  Temp_max  Temp_min  Wind_max  Precip
# Valls - IES Narcís Oller 41.308056   1.266667       225      19.9       9.2        23     NaN
